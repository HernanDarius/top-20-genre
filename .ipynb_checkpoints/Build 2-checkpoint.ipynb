# %%
import numpy as np
import pandas as pd

# %%
song_data=pd.read_csv(r'C:\Users\hdmec\Song Data\MillionSongsSubset.csv')

# %%
song_data.head()
# Out:
#    SongNumber              SongID  AlbumID  \
# 0           1  SOBQSLF12A8C139785   296721
# 1           2  SOMDTTT12A8C13F1CB   303421
# 2           3  SOGOJEP12AB018D355   675211
# 3           4  SOLAZFN12AB018A094   725669
# 4           5  SOJPZIX12AB018B2BD   769725
#
#                             AlbumName            ArtistID  ArtistLatitude  \
# 0              The Heart Of Christmas  ARLNSD41187FB4D9A0        42.50382
# 1                        Soul Friends  ARISHTQ1187FB3E6F0             NaN
# 2  Ghetto Fabolous [Explicit Version]  AR3FE581187FB3F90A             NaN
# 3                          Afro-Indio  AR1N6N61187FB4E25E        23.08330
# 4                   Riddim Of Silence  ARJJRZ41187FB4C856             NaN
#
#               ArtistLocation  ArtistLongitude        ArtistName  Danceability  \
# 0                      Italy         12.57347    Sergio Franchi           NaN
# 1                        NaN              NaN       Ben E. King           NaN
# 2                Brooklyn NY              NaN          Fabolous           NaN
# 3  Havana Cuba [Jesus Maria]        -82.41670  Mongo Santamaria           NaN
# 4                        NaN              NaN             Floor           NaN
#
#    ...  Energy  Key  KeyConfidence  Mode  ModeConfidence  \
# 0  ...     0.0    8          0.217     1           0.241
# 1  ...     0.0   10          0.608     1           0.596
# 2  ...     0.0    1          0.164     1           0.080
# 3  ...     0.0    2          0.579     0           0.696
# 4  ...     0.0    0          0.045     1           0.298
#
#                               Release  SongHotttness StartOfFadeOut  \
# 0              The Heart Of Christmas       0.641771        165.581
# 1                        Soul Friends            NaN        159.997
# 2  Ghetto Fabolous [Explicit Version]            NaN        212.869
# 3                          Afro-Indio            NaN        182.503
# 4                   Riddim Of Silence       0.266955        202.368
#
#                         Genre             TrackId
# 0                         NaN  TRAGGVT128F428F842
# 1        classic pop and rock  TRAGGSJ128F42A5AE1
# 2  hip hop rnb and dance hall  TRAGGKN12903CCA8EE
# 3                         NaN  TRAGGXK12903CDA84B
# 4                         NaN  TRAGGMY12903CD9533
#
# [5 rows x 33 columns]

# %%
top_20=song_data['Genre'].value_counts().head(20).index[:].tolist()

# %%
top_20
# Out:
# ['classic pop and rock',
#  'hip hop rnb and dance hall',
#  'rock and indie',
#  'folk',
#  'production music',
#  'pop and chart',
#  'finnish',
#  'french',
#  'soul and reggae',
#  'jazz and blues',
#  'german',
#  'uk | british | english | classic pop and rock',
#  'american',
#  'country',
#  'world',
#  'dance and electronica',
#  'classic pop and rock | folk',
#  'rock and indie | hip hop',
#  'blues',
#  'greek']

# %%
song_data['top_20_genre']=song_data['Genre'].isin(top_20)

# %%
song_data.head()
# Out:
#    SongNumber              SongID  AlbumID  \
# 0           1  SOBQSLF12A8C139785   296721
# 1           2  SOMDTTT12A8C13F1CB   303421
# 2           3  SOGOJEP12AB018D355   675211
# 3           4  SOLAZFN12AB018A094   725669
# 4           5  SOJPZIX12AB018B2BD   769725
#
#                             AlbumName            ArtistID  ArtistLatitude  \
# 0              The Heart Of Christmas  ARLNSD41187FB4D9A0        42.50382
# 1                        Soul Friends  ARISHTQ1187FB3E6F0             NaN
# 2  Ghetto Fabolous [Explicit Version]  AR3FE581187FB3F90A             NaN
# 3                          Afro-Indio  AR1N6N61187FB4E25E        23.08330
# 4                   Riddim Of Silence  ARJJRZ41187FB4C856             NaN
#
#               ArtistLocation  ArtistLongitude        ArtistName  Danceability  \
# 0                      Italy         12.57347    Sergio Franchi           NaN
# 1                        NaN              NaN       Ben E. King           NaN
# 2                Brooklyn NY              NaN          Fabolous           NaN
# 3  Havana Cuba [Jesus Maria]        -82.41670  Mongo Santamaria           NaN
# 4                        NaN              NaN             Floor           NaN
#
#    ...  Key  KeyConfidence  Mode  ModeConfidence  \
# 0  ...    8          0.217     1           0.241
# 1  ...   10          0.608     1           0.596
# 2  ...    1          0.164     1           0.080
# 3  ...    2          0.579     0           0.696
# 4  ...    0          0.045     1           0.298
#
#                               Release  SongHotttness  StartOfFadeOut  \
# 0              The Heart Of Christmas       0.641771         165.581
# 1                        Soul Friends            NaN         159.997
# 2  Ghetto Fabolous [Explicit Version]            NaN         212.869
# 3                          Afro-Indio            NaN         182.503
# 4                   Riddim Of Silence       0.266955         202.368
#
#                         Genre             TrackId  top_20_genre
# 0                         NaN  TRAGGVT128F428F842         False
# 1        classic pop and rock  TRAGGSJ128F42A5AE1          True
# 2  hip hop rnb and dance hall  TRAGGKN12903CCA8EE          True
# 3                         NaN  TRAGGXK12903CDA84B         False
# 4                         NaN  TRAGGMY12903CD9533         False
#
# [5 rows x 34 columns]

# %%
song_data['ArtistLocation'].isnull().sum()
# Out:
# 4292

# %%
song_data.dropna(subset=['Genre'], inplace=True)

# %%
song_data= song_data.drop('Genre', axis=1)

# %%
song_data.head()
# Out:
#     SongNumber              SongID  AlbumID  \
# 1            2  SOMDTTT12A8C13F1CB   303421
# 2            3  SOGOJEP12AB018D355   675211
# 5            6  SOHZHHE12A8C1360C0   144765
# 9           10  SOFAWJJ12AB0180A39   543041
# 10          11  SOLKBKQ12A8C13400C    87397
#
#                              AlbumName            ArtistID  ArtistLatitude  \
# 1                         Soul Friends  ARISHTQ1187FB3E6F0             NaN
# 2   Ghetto Fabolous [Explicit Version]  AR3FE581187FB3F90A             NaN
# 5         Quod Superius Sicut Inferius  ARF3L8J1187B9B7866        37.97615
# 9                                Aitai  ARVFGPJ1187B9A2477             NaN
# 10                     LIVE IN CONCERT  ARHT0B11187B993CB3        30.22032
#
#    ArtistLocation  ArtistLongitude         ArtistName  Danceability  ...  \
# 1             NaN              NaN        Ben E. King           NaN  ...
# 2     Brooklyn NY              NaN           Fabolous           NaN  ...
# 5   Athens Greece         23.73641            Astarte           NaN  ...
# 9             NaN              NaN  Michelle & Vickie           NaN  ...
# 10   Lafayette LA        -92.01705         Eddy Raven           NaN  ...
#
#     Energy  Key  KeyConfidence  Mode  ModeConfidence  \
# 1      0.0   10          0.608     1           0.596
# 2      0.0    1          0.164     1           0.080
# 5      0.0    4          0.596     0           0.566
# 9      0.0   10          0.226     0           0.519
# 10     0.0    5          0.920     1           0.658
#
#                                Release  SongHotttness StartOfFadeOut  \
# 1                         Soul Friends            NaN        159.997
# 2   Ghetto Fabolous [Explicit Version]            NaN        212.869
# 5         Quod Superius Sicut Inferius       0.443291        476.700
# 9                                Aitai            NaN        182.967
# 10                     LIVE IN CONCERT            NaN        204.852
#
#                TrackId  top_20_genre
# 1   TRAGGSJ128F42A5AE1          True
# 2   TRAGGKN12903CCA8EE          True
# 5   TRAGGVS128F4250CE8         False
# 9   TRAGGQQ128F931D8E1         False
# 10  TRAGGHA128F4262D55          True
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
sd_copy = song_data.copy()

# %%
do_not_need=['SongID','AlbumID','ArtistID','ArtistLatitude','ArtistLongitude',
             'Danceability','AlbumName','Release']
sd_copy=sd_copy.drop(do_not_need, axis=1)

# %%
sdbase_train,sdbase_test=train_test_split(sd_copy, test_size=0.20, random_state=42)
sdbase_train.shape, sdbase_test.shape
# Out:
# ((2968, 25), (742, 25))

# %%
sdbase_train, sdbase_val = train_test_split(sdbase_train, test_size = 0.20, random_state=42)
sdbase_train.shape, sdbase_val.shape
# Out:
# ((2374, 25), (594, 25))

# %%
target = ['top_20_genre']

x_train_base = sdbase_train.drop(target, axis=1)
y_train_base = sdbase_train[target]
x_val_base = sdbase_val.drop(target, axis=1)
y_val_base = sdbase_val[target]
x_test_base = sdbase_test.drop(target, axis=1)
y_test_base = sdbase_test[target]

# %%
print(x_train_base.shape, y_train_base.shape)
print(x_val_base.shape, y_val_base.shape)
print(x_test_base.shape, y_test_base.shape)
# Out:
# (2374, 24) (2374, 1)
# (594, 24) (594, 1)
# (742, 24) (742, 1)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import category_encoders as ce
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler

lr_base_model= make_pipeline(ce.OrdinalEncoder(),
                            IterativeImputer(),
                            StandardScaler(),
                            LinearRegression())
lr_base_model.fit(x_train_base, y_train_base)
print('Linear Regression R^2', lr_base_model.score(x_val_base, y_val_base))
# Out:
# Linear Regression R^2 0.025164760869478386

# %%
log_base_model= make_pipeline(ce.OrdinalEncoder(),
                            IterativeImputer(),
                            StandardScaler(),
                            LogisticRegression())
log_base_model.fit(x_train_base, y_train_base)
print('Training Accuracy', log_base_model.score(x_train_base, y_train_base))
print('Validation Accuracy', log_base_model.score(x_val_base, y_val_base))
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Training Accuracy 0.6983993260320135
# Validation Accuracy 0.7289562289562289

# %%
rf_base_model = make_pipeline(ce.OrdinalEncoder(),
                              IterativeImputer(),
                             RandomForestClassifier(random_state=42))
rf_base_model.fit(x_train_base, y_train_base)
print('Training Accuracy', rf_base_model.score(x_train_base, y_train_base))
print('Validation Accuracy', rf_base_model.score(x_val_base, y_val_base))
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\pipeline.py:335: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# Training Accuracy 1.0
# Validation Accuracy 0.7542087542087542

# %%
import eli5
from eli5.sklearn import PermutationImportance

transformers = make_pipeline(ce.OrdinalEncoder(),
                              IterativeImputer())
x_train_transformed = transformers.fit_transform(x_train_base)
x_val_transformed = transformers.transform(x_val_base)

rf_model = RandomForestClassifier(random_state=42,n_jobs=-1)
rf_model.fit(x_train_transformed,y_train_base)

feature_names = x_val_base.columns.tolist()

permuter = PermutationImportance(
rf_model,
scoring = 'accuracy',
n_iter = 5,
random_state=42)

permuter.fit(x_val_transformed, y_val_base)

eli5.show_weights(
permuter,
top=None,
feature_names=feature_names)
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\hdmec\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0229
#
#                     &plusmn; 0.0132
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ArtistFamiliarity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0185
#
#                     &plusmn; 0.0119
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ArtistHotttnesss
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0145
#
#                     &plusmn; 0.0062
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ArtistName
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0087
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Key
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0094
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Tempo
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0088
#
#                     &plusmn; 0.0117
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ArtistLocation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0074
#
#                     &plusmn; 0.0089
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Duration
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0071
#
#                     &plusmn; 0.0140
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Loudness
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0061
#
#                     &plusmn; 0.0132
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 StartOfFadeOut
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0057
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0039
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ModeConfidence
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0081
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 KeySignatureConfidence
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0101
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SongNumber
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0062
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EndOfFadeIn
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 TimeSignature
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Title
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AudioMd5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000

# %%
from sklearn.metrics import roc_curve, roc_auc_score

y_pred_prob_forest = rf_base_model.predict_proba(x_val_base)[:,-1]
fpr,tpr, thresholds = roc_curve(y_val_base, y_pred_prob_forest)

# %%
import matplotlib.pyplot as plt

plt.plot(fpr,tpr)

plt.title(' ROC Curve for Random Forest Base Model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %%
song_data
# Out:
#       SongNumber              SongID  AlbumID  \
# 1              2  SOMDTTT12A8C13F1CB   303421
# 2              3  SOGOJEP12AB018D355   675211
# 5              6  SOHZHHE12A8C1360C0   144765
# 9             10  SOFAWJJ12AB0180A39   543041
# 10            11  SOLKBKQ12A8C13400C    87397
# ...          ...                 ...      ...
# 9992        9993  SOKJUOW12AB0181545   358013
# 9995        9996  SOCHBZX12A8C141F2B   499661
# 9996        9997  SOOYKEK12A8C13B1DD   299387
# 9998        9999  SOVXFJX12A81C2387B   230740
# 9999       10000  SOMXGSM12A8C130A2C   192588
#
#                                   AlbumName            ArtistID  \
# 1                              Soul Friends  ARISHTQ1187FB3E6F0
# 2        Ghetto Fabolous [Explicit Version]  AR3FE581187FB3F90A
# 5              Quod Superius Sicut Inferius  ARF3L8J1187B9B7866
# 9                                     Aitai  ARVFGPJ1187B9A2477
# 10                          LIVE IN CONCERT  ARHT0B11187B993CB3
# ...                                     ...                 ...
# 9992                            Trasmazonia  ARK8EHO1187B9B71D1
# 9995  Get the Led Out - Led Zeppelin Salute  ARNPPTH1187B9AD429
# 9996                     The Preacher's Son  ARRJ3UC1187FB579D7
# 9998                                 LAViSH  ARWJEOP1187B996538
# 9999                          Alex Loves...  ARCEEC91187B9AC4FB
#
#       ArtistLatitude             ArtistLocation  ArtistLongitude  \
# 1                NaN                        NaN              NaN
# 2                NaN                Brooklyn NY              NaN
# 5           37.97615              Athens Greece         23.73641
# 9                NaN                        NaN              NaN
# 10          30.22032               Lafayette LA        -92.01705
# ...              ...                        ...              ...
# 9992        57.15382          Aberdeen Scotland         -2.10679
# 9995        51.48550   Heston Middlesex England         -0.37196
# 9996             NaN  Croix-des-Bouquets  Haiti              NaN
# 9998             NaN                        NaN              NaN
# 9999        44.97903             Minneapolis MN        -93.26493
#
#                                       ArtistName  Danceability  ...  Energy  \
# 1                                    Ben E. King           NaN  ...     0.0
# 2                                       Fabolous           NaN  ...     0.0
# 5                                        Astarte           NaN  ...     0.0
# 9                              Michelle & Vickie           NaN  ...     0.0
# 10                                    Eddy Raven           NaN  ...     0.0
# ...                                          ...           ...  ...     ...
# 9992                                      Shamen           NaN  ...     0.0
# 9995                                  Jimmy Page           NaN  ...     0.0
# 9996  Wyclef Jean featuring Prodigy of Mobb Deep           NaN  ...     0.0
# 9998                                 Soul Ballet           NaN  ...     0.0
# 9999                            Alexander O'Neal           NaN  ...     0.0
#
#       Key  KeyConfidence  Mode  ModeConfidence  \
# 1      10          0.608     1           0.596
# 2       1          0.164     1           0.080
# 5       4          0.596     0           0.566
# 9      10          0.226     0           0.519
# 10      5          0.920     1           0.658
# ...   ...            ...   ...             ...
# 9992    4          0.287     0           0.305
# 9995    2          0.471     0           0.412
# 9996    2          0.770     1           0.667
# 9998    4          0.279     0           0.295
# 9999    9          0.492     0           0.494
#
#                                     Release  SongHotttness StartOfFadeOut  \
# 1                              Soul Friends            NaN        159.997
# 2        Ghetto Fabolous [Explicit Version]            NaN        212.869
# 5              Quod Superius Sicut Inferius       0.443291        476.700
# 9                                     Aitai            NaN        182.967
# 10                          LIVE IN CONCERT            NaN        204.852
# ...                                     ...            ...            ...
# 9992                            Trasmazonia       0.265861        588.121
# 9995  Get the Led Out - Led Zeppelin Salute       0.499446        153.037
# 9996                     The Preacher's Son       0.439202        225.907
# 9998                                 LAViSH       0.609044        453.671
# 9999                          Alex Loves...       0.460485        259.692
#
#                  TrackId  top_20_genre
# 1     TRAGGSJ128F42A5AE1          True
# 2     TRAGGKN12903CCA8EE          True
# 5     TRAGGVS128F4250CE8         False
# 9     TRAGGQQ128F931D8E1         False
# 10    TRAGGHA128F4262D55          True
# ...                  ...           ...
# 9992  TRBCTBL128F931FF29         False
# 9995  TRBCTFW128F931FBE9         False
# 9996  TRBCTRX128F4299237          True
# 9998  TRBCTKV128F42222BD         False
# 9999  TRBCTEE128F42438DC         False
#
# [3710 rows x 33 columns]

# %%
def wrangle(X):
    
    unnecessary=['SongNumber','SongID','AlbumID','ArtistID','ArtistLatitude','ArtistLongitude','ArtistName',
                 'Danceability','AlbumName','Release','Energy','TrackId','AudioMd5','Title','SongHotttness',
                 'Key', 'KeySignatureConfidence','TimeSignature','Mode','KeyConfidence']
    
    X = X.copy().drop(unnecessary, axis=1)
    
    X.dropna(subset=['ArtistLocation','Year'], inplace=True)
    
    X=X.reset_index().drop('index',axis=1)
    
    return X

train_first = wrangle(song_data)
train_first.shape
# Out:
# (1899, 13)

# %%
train_first.head()
# Out:
#           ArtistLocation   Duration  KeySignature  Loudness    Tempo  \
# 0          Athens Greece  515.36934             4    -4.694  129.088
# 1           Lafayette LA  204.85179             5   -11.140  133.428
# 2            Wilmette IL  203.91138             2    -3.237  140.878
# 3         London England  204.14649             2    -4.556  114.902
# 4  Barking Essex England  180.19220             0   -17.810   81.256
#
#    TimeSignatureConfidence    Year  ArtistFamiliarity  ArtistHotttnesss  \
# 0                    0.453  2002.0           0.537088          0.352919
# 1                    0.061  1995.0           0.464994          0.344721
# 2                    0.930  2007.0           0.937965          0.566623
# 3                    0.000  1978.0           0.822433          0.531303
# 4                    1.000  2008.0           0.703691          0.529196
#
#    EndOfFadeIn  ModeConfidence  StartOfFadeOut  top_20_genre
# 0        0.427           0.566         476.700         False
# 1        0.000           0.658         204.852          True
# 2        0.000           0.270         191.216         False
# 3        0.444           0.420         192.830         False
# 4        0.000           0.558         169.407         False

# %%
train_first.isnull().sum()
# Out:
# ArtistLocation             0
# Duration                   0
# KeySignature               0
# Loudness                   0
# Tempo                      0
# TimeSignatureConfidence    0
# Year                       0
# ArtistFamiliarity          0
# ArtistHotttnesss           0
# EndOfFadeIn                0
# ModeConfidence             0
# StartOfFadeOut             0
# top_20_genre               0
# dtype: int64

# %%
train_first.apply(pd.Series.nunique)
# Out:
# ArtistLocation              395
# Duration                   1733
# KeySignature                 12
# Loudness                   1780
# Tempo                      1878
# TimeSignatureConfidence     668
# Year                         60
# ArtistFamiliarity           684
# ArtistHotttnesss            662
# EndOfFadeIn                 595
# ModeConfidence              664
# StartOfFadeOut             1851
# top_20_genre                  2
# dtype: int64

# %%
def train_val_test(X):
    ''' Will split a dataframe into seperate training, validation, and test sets'''
    X=X.copy()
    train,test=train_test_split(X, test_size=0.20, random_state=42)
    train, val = train_test_split(train, test_size = 0.20, random_state=42)
    
    return train, val, test

# %%
train, val, test = train_val_test(train_first)

# %%
train.shape, val.shape, test.shape
# Out:
# ((1215, 13), (304, 13), (380, 13))

# %%
train_top1 = train
val_top1 = val
test_top1 = test

# %%
target = ['top_20_genre']

x_train_top1 = train_top1.drop(target, axis=1)
y_train_top1 = train_top1[target]
x_val_top1 = val_top1.drop(target, axis=1)
y_val_top1 = val_top1[target]
x_test_top1 = test_top1.drop(target, axis=1)
y_test_top1 = test_top1[target]

# %%
x_train_top1.shape, y_train_top1.shape
# Out:
# ((1215, 12), (1215, 1))

# %%
log_top1_model= make_pipeline(ce.OrdinalEncoder(), 
                              LogisticRegression(max_iter=860,
                                               random_state=42))
log_top1_model.fit(x_train_top1, y_train_top1)
print('Training Accuracy', log_top1_model.score(x_train_top1, y_train_top1))
print('Validation Accuracy', log_top1_model.score(x_val_top1, y_val_top1))
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Training Accuracy 0.6962962962962963
# Validation Accuracy 0.7664473684210527
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
rf_top1_model = make_pipeline(ce.OrdinalEncoder(),
                             RandomForestClassifier(n_estimators =200,
                                                    oob_score=True,
                                                    max_depth=30,
                                                    max_leaf_nodes=40,
                                                    random_state=42,
                                                    warm_start=True,
                                                    n_jobs=-1)
                             )
rf_top1_model.fit(x_train_top1, y_train_top1)
print('Training Accuracy', rf_top1_model.score(x_train_top1, y_train_top1))
print('Validation Accuracy', rf_top1_model.score(x_val_top1, y_val_top1))
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\pipeline.py:335: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# Training Accuracy 0.8609053497942387
# Validation Accuracy 0.7631578947368421

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_top1_model = make_pipeline(ce.OrdinalEncoder(),
                             GradientBoostingClassifier(n_estimators=90,
                                                        min_samples_split=6,
                                                        min_samples_leaf=2,
                                                        max_depth=3,
                                                        random_state=42))

gb_top1_model.fit(x_train_top1, y_train_top1)
print('Training Accuracy', gb_top1_model.score(x_train_top1, y_train_top1))
print('Validation Accuracy', gb_top1_model.score(x_val_top1, y_val_top1))
print('Test Accuracy', gb_top1_model.score(x_test_top1, y_test_top1))
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Training Accuracy 0.8691358024691358
# Validation Accuracy 0.7598684210526315
# Test Accuracy 0.7447368421052631

# %%
from sklearn.metrics import accuracy_score
y_pred = gb_top1_model.predict(x_test_top1)
test_accuracy = accuracy_score(y_pred, y_test_top1)
print(test_accuracy)
# Out:
# 0.7447368421052631

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

labels = [False,True]
cm = confusion_matrix(y_test_top1, y_pred, labels)

ax=plt.subplot()
sns.heatmap(cm, annot=True, ax=ax, fmt='g');

plt.show()
# Out:
# C:\Users\hdmec\anaconda3\lib\site-packages\sklearn\utils\validation.py:71: FutureWarning: Pass labels=[False, True] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
